# %%
import mpbn
from colomoto_jupyter import tabulate

# %%
mbn = mpbn.MPBooleanNetwork({
    "a": "!b",
    "b": "!a",
    "c": "!a & b"
})

# %%
c0 = dict(a=0, b=0, c=0)
c1 = dict(a=1, b=1, c=1)
c2 = dict(a=0, b=1, c=0)

# %%
a = list(mbn.attractors())
tabulate(a)
# Out:
#    a  b  c
# 0  0  1  1
# 1  1  0  0

# %%
mbn.reachability(c0, c1)
# Out:
# True

# %%
mbn.reachability(c0, a[0])
# Out:
# True

# %%
mbn.reachability(a[1], a[0])
# Out:
# False

# %%
ra = mbn.attractors(reachable_from=c2)
tabulate(ra)
# Out:
#    a  b  c
# 0  0  1  1

# %%
tabulate(mbn.reachable_from(c2), reindex=True)
# Out:
#    a  b  c
# 0  0  1  0
# 1  0  1  1

# %%
tabulate(mbn.reachable_from(c2, reversed=True), reindex=True)
# Out:
#    a  b  c
# 0  0  0  0
# 1  0  0  1
# 2  0  1  0
# 3  1  1  0
# 4  1  1  1

# %%
mbn.dynamics()
# Out:
# # computing graph layout...
